# %%
import numpy as np
import glob
import os

# 1. Zip dosyasını açma
zip_file_name = "/content/fruits-360_dataset_100x100.zip"  # ZIP dosyanızın yolu
extract_path = "/content/fruits-360_dataset"      # Çıkartılacak hedef klasör

import zipfile
if not os.path.exists(extract_path):  # Daha önce açılmadıysa
    with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print(f"{zip_file_name} dosyası açıldı.")

# 2. Veri yolu tanımları
base_path = os.path.join(extract_path, "fruits-360_dataset_100x100/fruits-360/")
dim = 100  # Resim boyutu
# Out:
# /content/fruits-360_dataset_100x100.zip dosyası açıldı.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Parametreler
input_shape = (100, 100, 3)
num_classes = 141
train_dir = "/content/fruits-360_dataset/fruits-360_dataset_100x100/fruits-360/Training"
test_dir = "/content/fruits-360_dataset/fruits-360_dataset_100x100/fruits-360/Test"

# Basit bir CNN modeli oluşturma
def build_basic_cnn(input_shape, num_classes):
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        MaxPooling2D((2, 2)),

        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),

        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),

        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Modeli oluştur ve özetle
model = build_basic_cnn(input_shape, num_classes)
model.summary()

# ImageDataGenerator ile veri artırma ve yeniden ölçeklendirme
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    rotation_range=30,  # Veri artırma için
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)
test_datagen = ImageDataGenerator(rescale=1.0 / 255)

# Veri akışını oluşturma
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(100, 100),
    batch_size=64,  # Daha küçük batch size RAM için uygun olabilir
    class_mode='sparse'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(100, 100),
    batch_size=64,
    class_mode='sparse'
)

# Callback'ler: EarlyStopping ve Learning Rate Reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)

# Modeli eğitme
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=30,
    callbacks=[early_stopping, reduce_lr]
)

# Eğitim ve doğrulama sonuçlarını görselleştirme
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Doğruluk grafiği
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Kayıp grafiği
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 98, 98, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 49, 49, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 47, 47, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 23, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 21, 21, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 10, 10, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 12800)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       1,638,528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 141)                 │          18,189 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,749,965 (6.68 MB)
#  Trainable params: 1,749,965 (6.68 MB)
#  Non-trainable params: 0 (0.00 B)
# Found 70491 images belonging to 141 classes.
# Found 23619 images belonging to 141 classes.
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 252s 222ms/step - accuracy: 0.1864 - loss: 3.3469 - val_accuracy: 0.7968 - val_loss: 0.6717 - learning_rate: 0.0010
# Epoch 2/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 248s 223ms/step - accuracy: 0.6353 - loss: 1.0849 - val_accuracy: 0.8968 - val_loss: 0.3567 - learning_rate: 0.0010
# Epoch 3/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 259s 221ms/step - accuracy: 0.7154 - loss: 0.8375 - val_accuracy: 0.9135 - val_loss: 0.2991 - learning_rate: 0.0010
# Epoch 4/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 244s 221ms/step - accuracy: 0.7582 - loss: 0.6968 - val_accuracy: 0.9368 - val_loss: 0.2216 - learning_rate: 0.0010
# Epoch 5/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 245s 222ms/step - accuracy: 0.7905 - loss: 0.6091 - val_accuracy: 0.9363 - val_loss: 0.2233 - learning_rate: 0.0010
# Epoch 6/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 239s 216ms/step - accuracy: 0.8108 - loss: 0.5450 - val_accuracy: 0.9557 - val_loss: 0.1700 - learning_rate: 0.0010
# Epoch 7/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 239s 216ms/step - accuracy: 0.8352 - loss: 0.4791 - val_accuracy: 0.9577 - val_loss: 0.1676 - learning_rate: 0.0010
# Epoch 8/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 239s 216ms/step - accuracy: 0.8384 - loss: 0.4744 - val_accuracy: 0.9579 - val_loss: 0.1439 - learning_rate: 0.0010
# Epoch 9/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 265s 219ms/step - accuracy: 0.8613 - loss: 0.4038 - val_accuracy: 0.9621 - val_loss: 0.1417 - learning_rate: 0.0010
# Epoch 10/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 261s 218ms/step - accuracy: 0.8684 - loss: 0.3823 - val_accuracy: 0.9668 - val_loss: 0.1267 - learning_rate: 0.0010
# Epoch 11/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 262s 219ms/step - accuracy: 0.8785 - loss: 0.3543 - val_accuracy: 0.9697 - val_loss: 0.1086 - learning_rate: 0.0010
# Epoch 12/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 241s 218ms/step - accuracy: 0.8840 - loss: 0.3343 - val_accuracy: 0.9742 - val_loss: 0.1095 - learning_rate: 0.0010
# Epoch 13/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 254s 229ms/step - accuracy: 0.8873 - loss: 0.3212 - val_accuracy: 0.9753 - val_loss: 0.1166 - learning_rate: 0.0010
# Epoch 14/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 253s 221ms/step - accuracy: 0.8971 - loss: 0.2991 - val_accuracy: 0.9720 - val_loss: 0.1111 - learning_rate: 0.0010
# Epoch 15/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 240s 217ms/step - accuracy: 0.9231 - loss: 0.2188 - val_accuracy: 0.9785 - val_loss: 0.1133 - learning_rate: 5.0000e-04
# Epoch 16/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 244s 220ms/step - accuracy: 0.9325 - loss: 0.1960 - val_accuracy: 0.9834 - val_loss: 0.0890 - learning_rate: 5.0000e-04
# Epoch 17/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 258s 217ms/step - accuracy: 0.9337 - loss: 0.1887 - val_accuracy: 0.9858 - val_loss: 0.0834 - learning_rate: 5.0000e-04
# Epoch 18/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 251s 226ms/step - accuracy: 0.9364 - loss: 0.1828 - val_accuracy: 0.9840 - val_loss: 0.0806 - learning_rate: 5.0000e-04
# Epoch 19/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 250s 216ms/step - accuracy: 0.9372 - loss: 0.1764 - val_accuracy: 0.9867 - val_loss: 0.0846 - learning_rate: 5.0000e-04
# Epoch 20/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 272s 225ms/step - accuracy: 0.9404 - loss: 0.1709 - val_accuracy: 0.9866 - val_loss: 0.0707 - learning_rate: 5.0000e-04
# Epoch 21/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 251s 215ms/step - accuracy: 0.9458 - loss: 0.1582 - val_accuracy: 0.9878 - val_loss: 0.0741 - learning_rate: 5.0000e-04
# Epoch 22/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 245s 222ms/step - accuracy: 0.9449 - loss: 0.1583 - val_accuracy: 0.9875 - val_loss: 0.0768 - learning_rate: 5.0000e-04
# Epoch 23/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 244s 220ms/step - accuracy: 0.9484 - loss: 0.1489 - val_accuracy: 0.9866 - val_loss: 0.0699 - learning_rate: 5.0000e-04
# Epoch 24/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 236s 213ms/step - accuracy: 0.9510 - loss: 0.1425 - val_accuracy: 0.9831 - val_loss: 0.0691 - learning_rate: 5.0000e-04
# Epoch 25/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 261s 212ms/step - accuracy: 0.9537 - loss: 0.1399 - val_accuracy: 0.9837 - val_loss: 0.0807 - learning_rate: 5.0000e-04
# Epoch 26/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 260s 210ms/step - accuracy: 0.9552 - loss: 0.1320 - val_accuracy: 0.9820 - val_loss: 0.0752 - learning_rate: 5.0000e-04
# Epoch 27/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 272s 219ms/step - accuracy: 0.9550 - loss: 0.1319 - val_accuracy: 0.9890 - val_loss: 0.0745 - learning_rate: 5.0000e-04
# Epoch 28/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 255s 212ms/step - accuracy: 0.9644 - loss: 0.1051 - val_accuracy: 0.9896 - val_loss: 0.0543 - learning_rate: 2.5000e-04
# Epoch 29/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 263s 214ms/step - accuracy: 0.9670 - loss: 0.0965 - val_accuracy: 0.9894 - val_loss: 0.0685 - learning_rate: 2.5000e-04
# Epoch 30/30
# 1102/1102 ━━━━━━━━━━━━━━━━━━━━ 236s 213ms/step - accuracy: 0.9672 - loss: 0.0913 - val_accuracy: 0.9912 - val_loss: 0.0714 - learning_rate: 2.5000e-04

# %%
# Modeli kaydetme
model_save_path = "/content/fruits_cnn_model.keras"
model.save(model_save_path)

print(f"Model başarıyla {model_save_path} konumuna kaydedildi.")
# Out:
# Model başarıyla /content/fruits_cnn_model.keras konumuna kaydedildi.

# %%
from tensorflow.keras.models import Sequential, load_model

# Modeli tekrar yükleme ve test setinde değerlendirme
loaded_model = load_model(model_save_path)
test_loss, test_accuracy = loaded_model.evaluate(test_generator)

print(f"Yüklenen modelin Test Loss: {test_loss:.4f}")
print(f"Yüklenen modelin Test Accuracy: {test_accuracy:.4f}")
# Out:
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9888 - loss: 0.0628
# Yüklenen modelin Test Loss: 0.0543
# Yüklenen modelin Test Accuracy: 0.9896

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sns
import pandas as pd

# Test setindeki gerçek etiketleri ve tahminleri alın
y_true = test_generator.classes  # Test setinin gerçek sınıfları
y_pred = model.predict(test_generator)  # Tahmin edilen olasılıklar
y_pred_classes = np.argmax(y_pred, axis=1)  # Tahmin edilen sınıf indeksleri

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)
classes = list(test_generator.class_indices.keys())  # Sınıf isimleri

# Confusion Matrix görselleştirme
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Precision, Recall, F1-score
report = classification_report(y_true, y_pred_classes, target_names=classes)
print("Classification Report:")
print(report)
# Out:
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step
# Classification Report:
#                        precision    recall  f1-score   support
#
#               Apple 6       0.00      0.00      0.00       157
#      Apple Braeburn 1       0.01      0.01      0.01       164
#  Apple Crimson Snow 1       0.01      0.01      0.01       148
#        Apple Golden 1       0.00      0.00      0.00       160
#        Apple Golden 2       0.01      0.01      0.01       164
#        Apple Golden 3       0.00      0.00      0.00       161
#  Apple Granny Smith 1       0.01      0.01      0.01       164
#     Apple Pink Lady 1       0.01      0.01      0.01       152
#           Apple Red 1       0.02      0.02      0.02       164
#           Apple Red 2       0.00      0.00      0.00       164
#           Apple Red 3       0.00      0.00      0.00       144
# Apple Red Delicious 1       0.00      0.00      0.00       166
#    Apple Red Yellow 1       0.01      0.01      0.01       164
#    Apple Red Yellow 2       0.00      0.00      0.00       219
#           Apple hit 1       0.01      0.01      0.01       234
#             Apricot 1       0.01      0.01      0.01       164
#             Avocado 1       0.03      0.03      0.03       143
#        Avocado ripe 1       0.00      0.00      0.00       166
#              Banana 1       0.01      0.01      0.01       166
#  Banana Lady Finger 1       0.01      0.01      0.01       152
#          Banana Red 1       0.00      0.00      0.00       166
#            Beetroot 1       0.00      0.00      0.00       150
#           Blueberry 1       0.00      0.00      0.00       154
#       Cabbage white 1       0.00      0.00      0.00        47
#        Cactus fruit 1       0.01      0.01      0.01       166
#          Cantaloupe 1       0.01      0.01      0.01       164
#          Cantaloupe 2       0.00      0.00      0.00       164
#           Carambula 1       0.00      0.00      0.00       166
#              Carrot 1       0.00      0.00      0.00        50
#         Cauliflower 1       0.03      0.03      0.03       234
#              Cherry 1       0.00      0.00      0.00       164
#              Cherry 2       0.01      0.01      0.01       246
#      Cherry Rainier 1       0.02      0.02      0.02       246
#    Cherry Wax Black 1       0.01      0.01      0.01       164
#      Cherry Wax Red 1       0.01      0.01      0.01       164
#   Cherry Wax Yellow 1       0.00      0.00      0.00       164
#            Chestnut 1       0.00      0.00      0.00       153
#          Clementine 1       0.01      0.01      0.01       166
#               Cocos 1       0.01      0.01      0.01       166
#                Corn 1       0.02      0.01      0.02       150
#           Corn Husk 1       0.00      0.00      0.00       154
#            Cucumber 1       0.00      0.00      0.00        50
#            Cucumber 3       0.00      0.00      0.00        81
#       Cucumber Ripe 1       0.01      0.01      0.01       130
#       Cucumber Ripe 2       0.01      0.01      0.01       156
#               Dates 1       0.02      0.02      0.02       166
#            Eggplant 1       0.02      0.01      0.01       156
#       Eggplant long 1       0.00      0.00      0.00        80
#                 Fig 1       0.00      0.00      0.00       234
#         Ginger Root 1       0.01      0.01      0.01        99
#          Granadilla 1       0.01      0.01      0.01       166
#          Grape Blue 1       0.01      0.01      0.01       328
#          Grape Pink 1       0.02      0.02      0.02       164
#         Grape White 1       0.01      0.01      0.01       166
#         Grape White 2       0.01      0.01      0.01       166
#         Grape White 3       0.01      0.01      0.01       164
#         Grape White 4       0.01      0.01      0.01       158
#     Grapefruit Pink 1       0.01      0.01      0.01       166
#    Grapefruit White 1       0.01      0.01      0.01       164
#               Guava 1       0.01      0.01      0.01       166
#            Hazelnut 1       0.01      0.01      0.01       157
#         Huckleberry 1       0.00      0.00      0.00       166
#                Kaki 1       0.02      0.02      0.02       166
#                Kiwi 1       0.01      0.01      0.01       156
#            Kohlrabi 1       0.00      0.00      0.00       157
#            Kumquats 1       0.02      0.02      0.02       166
#               Lemon 1       0.01      0.01      0.01       164
#         Lemon Meyer 1       0.01      0.01      0.01       166
#               Limes 1       0.01      0.01      0.01       166
#              Lychee 1       0.00      0.00      0.00       166
#           Mandarine 1       0.01      0.01      0.01       166
#               Mango 1       0.01      0.01      0.01       166
#           Mango Red 1       0.01      0.01      0.01       142
#           Mangostan 1       0.01      0.01      0.01       102
#            Maracuja 1       0.01      0.01      0.01       166
#  Melon Piel de Sapo 1       0.01      0.01      0.01       246
#            Mulberry 1       0.00      0.00      0.00       164
#           Nectarine 1       0.00      0.00      0.00       164
#      Nectarine Flat 1       0.01      0.01      0.01       160
#          Nut Forest 1       0.02      0.02      0.02       218
#           Nut Pecan 1       0.02      0.02      0.02       178
#           Onion Red 1       0.01      0.01      0.01       150
#    Onion Red Peeled 1       0.01      0.01      0.01       155
#         Onion White 1       0.01      0.01      0.01       146
#              Orange 1       0.00      0.00      0.00       160
#              Papaya 1       0.01      0.01      0.01       164
#       Passion Fruit 1       0.01      0.01      0.01       166
#               Peach 1       0.01      0.01      0.01       164
#               Peach 2       0.02      0.02      0.02       246
#          Peach Flat 1       0.00      0.00      0.00       164
#                Pear 1       0.00      0.00      0.00       164
#                Pear 2       0.01      0.01      0.01       232
#                Pear 3       0.00      0.00      0.00        72
#          Pear Abate 1       0.00      0.00      0.00       166
#        Pear Forelle 1       0.02      0.02      0.02       234
#         Pear Kaiser 1       0.00      0.00      0.00       102
#        Pear Monster 1       0.01      0.01      0.01       166
#            Pear Red 1       0.01      0.01      0.01       222
#          Pear Stone 1       0.00      0.00      0.00       237
#       Pear Williams 1       0.03      0.03      0.03       166
#              Pepino 1       0.01      0.01      0.01       166
#        Pepper Green 1       0.01      0.01      0.01       148
#       Pepper Orange 1       0.00      0.00      0.00       234
#          Pepper Red 1       0.00      0.00      0.00       222
#       Pepper Yellow 1       0.01      0.01      0.01       222
#            Physalis 1       0.01      0.01      0.01       164
#  Physalis with Husk 1       0.01      0.01      0.01       164
#           Pineapple 1       0.01      0.01      0.01       166
#      Pineapple Mini 1       0.00      0.00      0.00       163
#        Pitahaya Red 1       0.02      0.02      0.02       166
#                Plum 1       0.01      0.01      0.01       151
#                Plum 2       0.00      0.00      0.00       142
#                Plum 3       0.01      0.01      0.01       304
#         Pomegranate 1       0.01      0.01      0.01       164
#      Pomelo Sweetie 1       0.01      0.01      0.01       153
#          Potato Red 1       0.01      0.01      0.01       150
#   Potato Red Washed 1       0.02      0.02      0.02       151
#        Potato Sweet 1       0.00      0.00      0.00       150
#        Potato White 1       0.00      0.00      0.00       150
#              Quince 1       0.01      0.01      0.01       166
#            Rambutan 1       0.00      0.00      0.00       164
#           Raspberry 1       0.02      0.02      0.02       166
#          Redcurrant 1       0.00      0.00      0.00       164
#               Salak 1       0.00      0.00      0.00       162
#          Strawberry 1       0.01      0.01      0.01       164
#    Strawberry Wedge 1       0.00      0.00      0.00       246
#           Tamarillo 1       0.01      0.01      0.01       166
#             Tangelo 1       0.00      0.00      0.00       166
#              Tomato 1       0.03      0.03      0.03       246
#              Tomato 2       0.01      0.01      0.01       225
#              Tomato 3       0.01      0.01      0.01       246
#              Tomato 4       0.00      0.00      0.00       160
#   Tomato Cherry Red 1       0.00      0.00      0.00       164
#        Tomato Heart 1       0.01      0.01      0.01       228
#       Tomato Maroon 1       0.00      0.00      0.00       127
#       Tomato Yellow 1       0.01      0.01      0.01       153
#  Tomato not Ripened 1       0.01      0.01      0.01       158
#              Walnut 1       0.02      0.02      0.02       249
#          Watermelon 1       0.00      0.00      0.00       157
#            Zucchini 1       0.00      0.00      0.00        80
#       Zucchini dark 1       0.00      0.00      0.00        80
#
#              accuracy                           0.01     23619
#             macro avg       0.01      0.01      0.01     23619
#          weighted avg       0.01      0.01      0.01     23619
